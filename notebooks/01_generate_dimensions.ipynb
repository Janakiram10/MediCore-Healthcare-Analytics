# %%
from pathlib import Path
import pandas as pd
import numpy as np

np.random.seed(42)

# Create MediCore folders in the SAME folder where notebook is running
CURRENT_DIR = Path.cwd()\n# Works whether Jupyter starts from the repository root or notebooks/\nBASE_DIR = CURRENT_DIR.parent if CURRENT_DIR.name == "notebooks" else CURRENT_DIR

RAW_DIR = BASE_DIR / "data" / "raw"
PROCESSED_DIR = BASE_DIR / "data" / "processed"
VALIDATION_DIR = BASE_DIR / "data" / "validation"

RAW_DIR.mkdir(parents=True, exist_ok=True)
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)
VALIDATION_DIR.mkdir(parents=True, exist_ok=True)

print("Current folder:")
print(BASE_DIR)

print("\nFolders created successfully:")
print(RAW_DIR)
print(PROCESSED_DIR)
print(VALIDATION_DIR)
